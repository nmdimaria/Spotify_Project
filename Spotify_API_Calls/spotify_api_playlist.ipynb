# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 

from config import clientID, clientSecret

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=clientID,\
                                                            client_secret=clientSecret))

# %%
# GETTING INFO FROM USER PLAYLIST
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

# Insert username and playlist id
ids = getTrackIDs('nmdimaria', '37i9dQZF1EuTCpDgLn8lAw')

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
#df.to_csv("spotify.csv", sep = ',')

# %%
df
# Out:
#                                                  name  \
# 0                                       Beverly Hills
# 1                                             A.D.H.D
# 2                      Slow Dancing in a Burning Room
# 3                                        Paper Trail$
# 4                                           Paralyzer
# 5                                 Like Real People Do
# 6                                   Since U Been Gone
# 7                          I Write Sins Not Tragedies
# 8                                        Up All Night
# 9                                  How Far We've Come
# 10                                        Stacy's Mom
# 11                                              Woman
# 12                                          Let It Go
# 13      I Don't Wanna Be In Love (Dance Floor Anthem)
# 14                           Over My Head (Cable Car)
# 15                                Dirty Little Secret
# 16                           Turtles All the Way Down
# 17                                   Thnks fr th Mmrs
# 18                                    Die A Happy Man
# 19                                  Doesn't Remind Me
# 20                                  Get Your Shine On
# 21                                         Wet Dreamz
# 22                                     Gives You Hell
# 23                                  Hey There Delilah
# 24                                          3's & 7's
# 25                                             Ho Hey
# 26                           You're Gonna Go Far, Kid
# 27                                        Springsteen
# 28                                   Check Yes Juliet
# 29                                    Howlin' for You
# 30    Ain't No Rest For The Wicked - Original Version
# 31                                     No Role Modelz
# 32   High School Never Ends - Main Version - Explicit
# 33                                    Round Here Buzz
# 34  Free Fallin' - Live at the Nokia Theatre, Los ...
# 35                                     Shooting Stars
# 36                                On Top Of The World
# 37                                         Move Along
# 38                           One Kiss (with Dua Lipa)
# 39                 Nine in the Afternoon - Single Mix
# 40                                    Everybody Talks
# 41                                   The Great Escape
# 42                                              IDGAF
# 43                                           Rockstar
# 44                                        Stacy's Mom
# 45                                            Gravity
# 46                         Magic (feat. Rivers Cuomo)
# 47                               Smoke A Little Smoke
# 48                                            Georgia
# 49                 Lord Pretty Flacko Jodye 2 (LPFJ2)
#
#                                                 album  \
# 0                                        Make Believe
# 1                                          Section.80
# 2                                           Continuum
# 3                                            B4.DA.$$
# 4                Them Vs. You Vs. Me (Deluxe Edition)
# 5                                              Hozier
# 6                                           Breakaway
# 7                         A Fever You Can't Sweat Out
# 8                                      Thank Me Later
# 9                                  How Far We've Come
# 10                        Welcome Interstate Managers
# 11                                         Wolfmother
# 12                                 Chaos And The Calm
# 13                               Good Morning Revival
# 14                                 How To Save A Life
# 15                                         Move Along
# 16                 Metamodern Sounds in Country Music
# 17                                   Infinity On High
# 18                                         Tangled Up
# 19                                       Out of Exile
# 20                           Here's To The Good Times
# 21                            2014 Forest Hills Drive
# 22                          When The World Comes Down
# 23                                 All That We Needed
# 24                                       Era Vulgaris
# 25                     The Lumineers (Deluxe Edition)
# 26                      Rise And Fall, Rage And Grace
# 27                                              Chief
# 28                                       We The Kings
# 29                                           Brothers
# 30                                  Cage The Elephant
# 31                            2014 Forest Hills Drive
# 32                   The Great Burrito Extortion Case
# 33                                  Mr. Misunderstood
# 34  Where the Light Is: John Mayer Live In Los Ang...
# 35                               Bag Raiders (Deluxe)
# 36                                      Night Visions
# 37                                         Move Along
# 38                           One Kiss (with Dua Lipa)
# 39                                       Pretty. Odd.
# 40                                       Picture Show
# 41                                    Boys Like Girls
# 42                                  Dua Lipa (Deluxe)
# 43  All the Right Reasons (Walmart Exclusive Edition)
# 44                 I’ve Never Done Anything Like This
# 45                                          Continuum
# 46        B.o.B Presents: The Adventures of Bobby Ray
# 47                                           Carolina
# 48                               Dream Your Life Away
# 49                                  AT.LONG.LAST.A$AP
#
#                       artist release_date  length  popularity  danceability  \
# 0                     Weezer   2005-05-10  196093          70         0.693
# 1             Kendrick Lamar   2011-07-02  215509          71         0.609
# 2                 John Mayer   2006-09-11  242000          75         0.668
# 3                Joey Bada$$   2015-01-20  194738          15         0.548
# 4              Finger Eleven   2007-01-01  208106          71         0.644
# 5                     Hozier   2014-07-20  198029          65         0.569
# 6             Kelly Clarkson         2004  188960          71         0.662
# 7        Panic! At The Disco   2005-09-27  186634          75         0.569
# 8                      Drake   2010-01-01  234333          63         0.606
# 9            Matchbox Twenty   2007-09-15  211022          55         0.566
# 10        Fountains Of Wayne   2003-01-01  197986          74         0.774
# 11                Wolfmother   2005-01-01  175666          61         0.191
# 12                 James Bay   2014-12-15  260533          74         0.546
# 13            Good Charlotte   2007-03-16  244000          59         0.640
# 14                  The Fray   2005-09-13  236266          70         0.592
# 15  The All-American Rejects   2005-01-01  193653          71         0.465
# 16          Sturgill Simpson   2014-05-09  188186          23         0.552
# 17              Fall Out Boy   2007-01-01  203506          77         0.459
# 18              Thomas Rhett   2015-01-01  227426          75         0.595
# 19                Audioslave   2005-01-01  255000          65         0.457
# 20      Florida Georgia Line   2012-01-01  222013          62         0.497
# 21                   J. Cole   2014-12-09  239320          79         0.517
# 22  The All-American Rejects   2008-01-01  213106          73         0.718
# 23           Plain White T's   2005-01-01  232533          81         0.656
# 24   Queens of the Stone Age   2007-01-01  214066          57         0.438
# 27      0.100000         0.692   0.809          0.000098    0.1850    -5.935
# 28      0.002400         0.350   0.909          0.000000    0.1630    -4.204
# 29      0.028000         0.705   0.735          0.078300    0.1120    -6.646
# 30      0.059700         0.635   0.914          0.000000    0.6010    -5.631
# 31      0.301000         0.692   0.521          0.000000    0.0565    -8.465
# 32      0.012200         0.536   0.923          0.000000    0.1420    -3.494
# 33      0.042200         0.638   0.441          0.000013    0.1070    -9.064
# 34      0.771000         0.315   0.296          0.000000    0.7020   -13.262
# 35      0.089300         0.636   0.720          0.017800    0.0868    -6.195
# 36      0.084100         0.631   0.924          0.000004    0.0840    -5.589
# 37      0.000148         0.518   0.916          0.000000    0.2910    -3.858
# 38      0.037000         0.791   0.862          0.000022    0.0814    -3.240
# 39      0.084300         0.405   0.689          0.000000    0.2070    -5.750
# 40      0.003010         0.471   0.924          0.000000    0.3130    -3.906
# 41      0.001660         0.423   0.940          0.000000    0.1780    -4.012
# 42      0.040300         0.836   0.544          0.000000    0.0824    -5.975
# 43      0.045900         0.616   0.910          0.000000    0.3430    -3.004
# 44      0.003490         0.728   0.801          0.000195    0.0907    -3.636
# 45      0.731000         0.764   0.326          0.001300    0.2400    -9.883
# 46      0.012700         0.549   0.932          0.000000    0.3470    -4.110
# 47      0.020600         0.770   0.641          0.000230    0.1060    -6.077
# 48      0.312000         0.388   0.660          0.000307    0.0943    -7.372
# 49      0.012300         0.485   0.720          0.000000    0.0546    -5.991
#
#     speechiness    tempo  time_signature
# 0        0.0726   87.904               4
# 1        0.2400  157.740               4
# 2        0.0273  134.150               5
# 3        0.2850   93.620               4
# 4        0.0456  106.031               4
# 5        0.0298   70.060               3
# 6        0.0322  130.999               4
# 7        0.1400  170.094               4
# 8        0.2780  156.347               4
# 9        0.0642   83.000               4
# 10       0.0412  118.015               4
# 11       0.2170  150.753               4
# 12       0.0288  147.464               4
# 13       0.0428  124.968               4
# 14       0.0448  116.030               4
# 15       0.0440  143.850               4
# 16       0.0418   91.362               4
# 17       0.0623  154.837               4
# 18       0.0349  166.052               4
# 19       0.0378   99.739               4
# 20       0.0371   96.991               4
# 21       0.3640  175.906               4
# 22       0.0387  100.008               4
# 23       0.0293  103.971               4
# 24       0.1080  131.306               4
# 25       0.0301   79.907               4
# 26       0.0638  126.115               4
# 27       0.0255  104.023               4
# 28       0.0774  166.866               4
# 29       0.0931  132.627               4
# 30       0.1110  156.014               4
# 31       0.3300  100.450               4
# 32       0.1250  160.030               4
# 33       0.0347   76.078               4
# 34       0.0317  172.638               4
# 35       0.0432  124.944               4
# 36       0.1460  100.045               4
# 37       0.0454  109.864               4
# 38       0.1100  123.994               4
# 39       0.0365  155.189               4
# 40       0.0586  154.961               4
# 41       0.0635  149.934               4
# 42       0.0943   97.028               4
# 43       0.0386  144.073               4
# 44       0.0752  119.989               4
# 45       0.0342  123.980               3
# 46       0.3430   82.439               4
# 47       0.0350   96.980               4
# 48       0.0308  143.554               4
# 49       0.1270  207.982               4
